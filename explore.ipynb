# %% [markdown]
# # Exploration of the filtration class

# %%
from matplotlib import pyplot as plt
import numpy as np
import random
import gudhi

# %%
data = [random.randint(0,10) for i in range(10)]
plt.plot(data)

# %%
data
# Out:
# [0, 0, 3, 8, 7, 5, 5, 0, 4, 3]

# %%
simplex = gudhi.SimplexTree()
        # First we insert the vertices of the time series
for idx, value in enumerate(data):
    simplex.insert(
        [idx], # 0-simplex
        filtration=value # the ordering on our vertices
        # is the values of the time series
    )
# Second, we insert the edges of the time series
for idx, value in enumerate(data):
    simplex.insert(
        [idx, idx+1], # 1-simplex
        filtration=value
    )
simplex.initialize_filtration()
# Out:
# /tmp/ipykernel_1231744/3735640951.py:15: DeprecationWarning: Since Gudhi 3.2, calling SimplexTree.initialize_filtration is unnecessary.
#   simplex.initialize_filtration()

# %%
simplex.persistence()
# Out:
# [(0, (0.0, inf)), (0, (0.0, 8.0)), (0, (3.0, 4.0))]
