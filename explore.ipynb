# %% [markdown]
# # Exploration of the filtration class

# %%
from matplotlib import pyplot as plt
import numpy as np
import random
from src.filtration import Filtration

# %%
data = [random.randint(0,10) for i in range(1000)]
plt.plot(data)

# %%
filtration = Filtration(data)
filtration.compute_persistence()

print(filtration.persistence)
# Out:
# [[ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 0. 10.]
#  [ 1. 10.]
#  [ 0.  9.]
#  [ 1. 10.]
#  [ 1. 10.]
#  [ 0.  9.]
#  [ 1. 10.]
#  [ 0.  9.]
#  [ 0.  9.]
#  [ 0.  9.]
#  [ 0.  9.]
#  [ 0.  9.]
#  [ 0.  9.]
#  [ 0.  9.]
#  [ 0.  9.]
#  [ 0.  9.]
#  [ 0.  9.]
#  [ 0.  9.]
#  [ 1. 10.]
#  [ 1. 10.]
#  [ 1. 10.]
#  [ 1. 10.]
#  [ 1. 10.]
#  [ 1. 10.]
#  [ 1. 10.]
#  [ 1. 10.]
#  [ 1. 10.]
#  [ 1.  9.]
#  [ 1.  9.]
#  [ 0.  8.]
#  [ 0.  8.]
#  [ 1.  9.]
#  [ 1.  9.]
#  [ 0.  8.]
#  [ 0.  8.]
# ...

# %%
filtration._plot_persistence_diagram()

# %%
image = filtration.persistent_image(
    resolution=[10,10],
    bandwidth=0.01,
)
print(image)
plt.imshow(np.flip(np.reshape(image[0], [10,10]), 0))
plt.title("Persistence Image")
# Out:
# [[ 1591.54943092     0.          9549.29658551  3183.09886184
#    4774.64829276  3183.09886184  3183.09886184  6366.19772368
#    1591.54943092  1591.54943092  3183.09886184  3183.09886184
#   11140.84601643 14323.94487827  7957.74715459  6366.19772368
#    4774.64829276  6366.19772368     0.             0.
#    1591.54943092  7957.74715459  9549.29658551  9549.29658551
#    9549.29658551  4774.64829276  9549.29658551     0.
#       0.             0.             0.          9549.29658551
#    6366.19772368 17507.04374011  7957.74715459  9549.29658551
#    6366.19772368     0.             0.             0.
#    1591.54943092 14323.94487827 11140.84601643 12732.39544735
#    9549.29658551  1591.54943092     0.             0.
#       0.             0.          1591.54943092 11140.84601643
#   17507.04374011  9549.29658551  3183.09886184     0.
#       0.             0.             0.             0.
#    7957.74715459 14323.94487827 23873.24146378 12732.39544735
# ...

# %%
import gudhi.representations
